# %%
# !pip install pandas numpy matplotlib scipy librosa soundfile
# Out:
# ...
#   Using cached librosa-0.11.0-py3-none-any.whl (260 kB)
# ...
#   Using cached soundfile-0.13.1-py2.py3-none-win_amd64.whl (1.0 MB)
# ...
#      ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.1 MB 1.3 MB/s eta 0:00:09
#      --------------------------------------- 0.1/11.1 MB 656.4 kB/s eta 0:00:17
#      --------------------------------------- 0.1/11.1 MB 930.9 kB/s eta 0:00:12
#       --------------------------------------- 0.2/11.1 MB 1.3 MB/s eta 0:00:09
#      - -------------------------------------- 0.3/11.1 MB 1.3 MB/s eta 0:00:09
#      - -------------------------------------- 0.4/11.1 MB 1.4 MB/s eta 0:00:08
#      - -------------------------------------- 0.6/11.1 MB 1.7 MB/s eta 0:00:07
#      -- ------------------------------------- 0.7/11.1 MB 2.0 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.2/11.1 MB 3.0 MB/s eta 0:00:04
# ...

# %%
import json

# %%
# !pip install PyWavelets
# Out:
# ...
#      ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.2 MB 660.6 kB/s eta 0:00:07
#       --------------------------------------- 0.1/4.2 MB 544.7 kB/s eta 0:00:08
#      - -------------------------------------- 0.1/4.2 MB 804.6 kB/s eta 0:00:06
#      -- ------------------------------------- 0.2/4.2 MB 1.2 MB/s eta 0:00:04
#      --- ------------------------------------ 0.3/4.2 MB 1.3 MB/s eta 0:00:03
#      --- ------------------------------------ 0.4/4.2 MB 1.3 MB/s eta 0:00:03
#      ------ --------------------------------- 0.6/4.2 MB 1.9 MB/s eta 0:00:02
#      -------- ------------------------------- 0.9/4.2 MB 2.3 MB/s eta 0:00:02
#      ------------ --------------------------- 1.3/4.2 MB 3.0 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.8/4.2 MB 3.9 MB/s eta 0:00:01
#      ---------------------- ----------------- 2.4/4.2 MB 4.6 MB/s eta 0:00:01
# ...
